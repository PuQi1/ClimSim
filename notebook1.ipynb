# %%
pip install .
# Out:
# Processing e:\github\climsim
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: xarray in d:\anaconda3\lib\site-packages (from climsim-utils==0.0.1) (2022.11.0)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from climsim-utils==0.0.1) (1.24.3)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from climsim-utils==0.0.1) (1.5.3)
# Requirement already satisfied: matplotlib in d:\anaconda3\lib\site-packages (from climsim-utils==0.0.1) (3.7.1)
# Collecting tensorflow (from climsim-utils==0.0.1)
#   Using cached tensorflow-2.14.0-cp311-cp311-win_amd64.whl (2.1 kB)
# Collecting netCDF4 (from climsim-utils==0.0.1)
#   Downloading netCDF4-1.6.4-cp311-cp311-win_amd64.whl (6.6 MB)
#                                               0.0/6.6 MB ? eta -:--:--
#      --                                       0.4/6.6 MB 12.2 MB/s eta 0:00:01
#      ------                                   1.1/6.6 MB 11.5 MB/s eta 0:00:01
#      ------------                             2.0/6.6 MB 14.5 MB/s eta 0:00:01
#      -----------------                        2.8/6.6 MB 15.1 MB/s eta 0:00:01
#      ---------------------                    3.6/6.6 MB 15.3 MB/s eta 0:00:01
#      --------------------------               4.4/6.6 MB 15.6 MB/s eta 0:00:01
#      -------------------------------          5.2/6.6 MB 16.0 MB/s eta 0:00:01
#      ------------------------------------     6.1/6.6 MB 16.1 MB/s eta 0:00:01
#      ---------------------------------------  6.6/6.6 MB 16.1 MB/s eta 0:00:01
#      ---------------------------------------- 6.6/6.6 MB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: h5py in d:\anaconda3\lib\site-packages (from climsim-utils==0.0.1) (3.7.0)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from climsim-utils==0.0.1) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (2.8.2)
# Collecting cftime (from netCDF4->climsim-utils==0.0.1)
#   Downloading cftime-1.6.2-cp311-cp311-win_amd64.whl (160 kB)
#                                               0.0/160.7 kB ? eta -:--:--
#      -------------------------------------- 160.7/160.7 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi in d:\anaconda3\lib\site-packages (from netCDF4->climsim-utils==0.0.1) (2023.7.22)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->climsim-utils==0.0.1) (2022.7)
# Requirement already satisfied: tensorflow-intel==2.14.0 in d:\anaconda3\lib\site-packages (from tensorflow->climsim-utils==0.0.1) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (4.24.4)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (67.8.0)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.14.0)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm->climsim-utils==0.0.1) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.29.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.26.16)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.2.2)
# Building wheels for collected packages: climsim-utils
#   Building wheel for climsim-utils (setup.py): started
#   Building wheel for climsim-utils (setup.py): finished with status 'done'
#   Created wheel for climsim-utils: filename=climsim_utils-0.0.1-py3-none-any.whl size=14558 sha256=045dac13f3d18a0cbd24c7f341088fb5d3e9469e2c9c0eeb105dfea64531436d
#   Stored in directory: C:\Users\spq\AppData\Local\Temp\pip-ephem-wheel-cache-1cj2gmww\wheels\d7\42\31\e2b51e685c937bcbb77a407adfe799c65288eb01d0d7bceb2c
# Successfully built climsim-utils
# Installing collected packages: cftime, netCDF4, tensorflow, climsim-utils
# Successfully installed cftime-1.6.2 climsim-utils-0.0.1 netCDF4-1.6.4 tensorflow-2.14.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting tensorflow
#   Downloading tensorflow-2.14.0-cp311-cp311-win_amd64.whl (2.1 kB)
# Collecting tensorflow-intel==2.14.0 (from tensorflow)
#   Downloading tensorflow_intel-2.14.0-cp311-cp311-win_amd64.whl (284.2 MB)
MB 1.9 MB/s eta 0:00:02
#      ---------------------------------        20.7/24.4 MB 1.9 MB/s eta 0:00:02
#      ---------------------------------        20.7/24.4 MB 1.9 MB/s eta 0:00:02
#      ---------------------------------        20.7/24.4 MB 1.9 MB/s eta 0:00:02
#      ---------------------------------        20.7/24.4 MB 1.9 MB/s eta 0:00:02
#      ---------------------------------        20.7/24.4 MB 1.9 MB/s eta 0:00:02
#      ---------------------------------        20.7/24.4 MB 1.9 MB/s eta 0:00:02
#      ----------------------------------       20.8/24.4 MB 1.8 MB/s eta 0:00:03
#      -----------------------------------      21.6/24.4 MB 1.8 MB/s eta 0:00:02
#      -----------------------------------      21.9/24.4 MB 1.8 MB/s eta 0:00:02
#      -----------------------------------      21.9/24.4 MB 1.8 MB/s eta 0:00:02
#      -----------------------------------      21.9/24.4 MB 1.8 MB/s eta 0:00:02
#      -----------------------------------      21.9/24.4 MB 1.8 MB/s eta 0:00:02
#      -----------------------------------      21.9/24.4 MB 1.8 MB/s eta 0:00:02
#      -------------------------------------    22.6/24.4 MB 1.9 MB/s eta 0:00:01
#      --------------------------------------   23.3/24.4 MB 1.9 MB/s eta 0:00:01
#      ---------------------------------------  24.0/24.4 MB 1.9 MB/s eta 0:00:01
#      ---------------------------------------  24.4/24.4 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------  24.4/24.4 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------- 24.4/24.4 MB 5.0 MB/s eta 0:00:00
# Collecting ml-dtypes==0.2.0 (from tensorflow-intel==2.14.0->tensorflow)
#   Downloading ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl (938 kB)
#                                               0.0/938.7 kB ? eta -:--:--
#      -------------------------------       788.5/938.7 kB 16.6 MB/s eta 0:00:01
#      ------------------------------------- 938.7/938.7 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.5 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.24.3)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.14.0->tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#                                               0.0/65.5 kB ? eta -:--:--
#      ---------------------------------------- 65.5/65.5 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.14.0->tensorflow)
#   Downloading protobuf-4.24.4-cp310-abi3-win_amd64.whl (430 kB)
#                                               0.0/430.5 kB ? eta -:--:--
#      ------------------------------------- 430.5/430.5 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (67.8.0)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.14.0->tensorflow)
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.14.0->tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl (1.5 MB)
#                                               0.0/1.5 MB ? eta -:--:--
#      ------------------                       0.7/1.5 MB 21.8 MB/s eta 0:00:01
#      -----------------------------------      1.3/1.5 MB 16.8 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 13.5 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.14.0->tensorflow)
#   Downloading grpcio-1.59.0-cp311-cp311-win_amd64.whl (3.7 MB)
#                                               0.0/3.7 MB ? eta -:--:--
#      ---------                                0.9/3.7 MB 14.4 MB/s eta 0:00:01
#      ----------------                         1.5/3.7 MB 16.3 MB/s eta 0:00:01
#      -----------------------                  2.1/3.7 MB 15.2 MB/s eta 0:00:01
#      --------------------------------         2.9/3.7 MB 15.6 MB/s eta 0:00:01
#      ---------------------------------------  3.6/3.7 MB 15.4 MB/s eta 0:00:01
#      ---------------------------------------  3.7/3.7 MB 15.6 MB/s eta 0:00:01
#      ---------------------------------------- 3.7/3.7 MB 13.0 MB/s eta 0:00:00
# Collecting tensorboard<2.15,>=2.14 (from tensorflow-intel==2.14.0->tensorflow)
#   Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#                                               0.0/5.5 MB ? eta -:--:--
#      ----                                     0.6/5.5 MB 13.3 MB/s eta 0:00:01
#      ---------                                1.3/5.5 MB 16.7 MB/s eta 0:00:01
#      ------------                             1.7/5.5 MB 15.4 MB/s eta 0:00:01
#      ------------                             1.7/5.5 MB 10.8 MB/s eta 0:00:01
#      --------------                           2.0/5.5 MB 10.0 MB/s eta 0:00:01
#      -----------------                        2.4/5.5 MB 10.1 MB/s eta 0:00:01
#      --------------------                     2.8/5.5 MB 10.1 MB/s eta 0:00:01
#      -------------------------                3.5/5.5 MB 10.2 MB/s eta 0:00:01
#      -----------------------------            4.1/5.5 MB 10.8 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------------          4.4/5.5 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------        4.5/5.5 MB 4.2 MB/s eta 0:00:01
#      --------------------------------------   5.3/5.5 MB 4.7 MB/s eta 0:00:01
#      ---------------------------------------  5.5/5.5 MB 4.8 MB/s eta 0:00:01
#      ---------------------------------------- 5.5/5.5 MB 4.6 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow-intel==2.14.0->tensorflow)
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#                                               0.0/440.7 kB ? eta -:--:--
#      ------------------------------------- 440.7/440.7 kB 13.9 MB/s eta 0:00:00
# Collecting keras<2.15,>=2.14.0 (from tensorflow-intel==2.14.0->tensorflow)
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#                                               0.0/1.7 MB ? eta -:--:--
#      -------------------                      0.8/1.7 MB 17.4 MB/s eta 0:00:01
#      --------------------                     0.9/1.7 MB 18.3 MB/s eta 0:00:01
#      --------------------                     0.9/1.7 MB 18.3 MB/s eta 0:00:01
#      ---------------------------              1.2/1.7 MB 8.3 MB/s eta 0:00:01
#      ---------------------------              1.2/1.7 MB 6.8 MB/s eta 0:00:01
#      ---------------------------              1.2/1.7 MB 6.8 MB/s eta 0:00:01
#      ---------------------------              1.2/1.7 MB 6.8 MB/s eta 0:00:01
#      ---------------------------              1.2/1.7 MB 6.8 MB/s eta 0:00:01
#      ---------------------------              1.2/1.7 MB 6.8 MB/s eta 0:00:01
#      -------------------------------------    1.6/1.7 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------  1.7/1.7 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow)
#   Downloading google_auth-2.23.3-py2.py3-none-any.whl (182 kB)
#                                               0.0/182.3 kB ? eta -:--:--
#      -------------------------------------- 182.3/182.3 kB 5.6 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.29.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow)
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#                                               0.0/151.7 kB ? eta -:--:--
#      -------------------------------------- 151.7/151.7 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, protobuf, opt-einsum, oauthlib, ml-dtypes, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed absl-py-2.0.0 astunparse-1.6.3 cachetools-5.3.1 flatbuffers-23.5.26 gast-0.5.4 google-auth-2.23.3 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.59.0 keras-2.14.0 libclang-16.0.6 ml-dtypes-0.2.0 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.24.4 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.14.1 tensorboard-data-server-0.7.1 tensorflow-2.14.0 tensorflow-estimator-2.14.0 tensorflow-intel-2.14.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.3.0

# %%
from climsim_utils.data_utils import *

# %%
import xarray as xr

# %%
help(data_utils)
# Out:
# Help on class data_utils in module climsim_utils.data_utils:
#
# class data_utils(builtins.object)
#  |  data_utils(grid_info, input_mean, input_max, input_min, output_scale)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, grid_info, input_mean, input_max, input_min, output_scale)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  calc_CRPS(self, preds, target, avg_grid=True)
#  |      calculate 'globally averaged' continuous ranked probability score
#  |      for vertically-resolved variables, input shape should be time x grid x level x num_crps_samples
#  |      for scalars, input shape should be time x grid x num_crps_samples
#  |
#  |      returns vector of length level or 1
#  |
#  |  calc_MAE(self, pred, target, avg_grid=True)
#  |      calculate 'globally averaged' mean absolute error
#  |      for vertically-resolved variables, shape should be time x grid x level
#  |      for scalars, shape should be time x grid
#  |
#  |      returns vector of length level or 1
#  |
#  |  calc_R2(self, pred, target, avg_grid=True)
#  |      calculate 'globally averaged' R-squared
#  |      for vertically-resolved variables, input shape should be time x grid x level
#  |      for scalars, input shape should be time x grid
#  |
#  |      returns vector of length level or 1
#  |
#  |  calc_RMSE(self, pred, target, avg_grid=True)
#  |      calculate 'globally averaged' root mean squared error
#  |      for vertically-resolved variables, shape should be time x grid x level
#  |      for scalars, shape should be time x grid
#  |
#  |      returns vector of length level or 1
#  |
#  |  calc_bias(self, pred, target, avg_grid=True)
#  |      calculate bias
#  |      for vertically-resolved variables, input shape should be time x grid x level
#  |      for scalars, input shape should be time x grid
#  |
#  |      returns vector of length level or 1
#  |
#  |  create_metrics_df(self, data_split)
#  |      creates a dataframe of metrics for each model
#  |
#  |  get_filelist(self, data_split)
#  |      This function returns the filelist corresponding to data splits for train, val, scoring, and test.
#  |
#  |  get_input(self, input_file)
#  |      This function reads in a file and returns an xarray dataset with the input variables for the emulator.
#  |
#  |  get_pressure_grid_plotting(self, data_split)
#  |      This function creates the temporally and zonally averaged pressure grid corresponding to a given data split.
#  |
#  |  get_target(self, input_file)
#  |      This function reads in a file and returns an xarray dataset with the target variables for the emulator.
#  |
#  |  get_xrdata(self, file, file_vars=None)
#  |      This function reads in a file and returns an xarray dataset with the variables specified.
#  |      file_vars must be a list of strings.
#  |
#  |  load_ncdata_with_generator(self, data_split)
#  |      This function works as a dataloader when training the emulator with raw netCDF files.
#  |      This can be used as a dataloader during training or it can be used to create entire datasets.
#  |      When used as a dataloader for training, I/O can slow down training considerably.
#  |      This function also normalizes the data.
#  |      mli corresponds to input
#  |      mlo corresponds to target
#  |
#  |  output_weighting(self, output, data_split)
#  |      This function does four transformations, and assumes we are using V1 variables:
#  |      [0] Undos the output scaling
#  |      [1] Weight vertical levels by dp/g
#  |      [2] Weight horizontal area of each grid cell by a[x]/mean(a[x])
#  |      [3] Unit conversion to a common energy unit
#  |
#  |  plot_r2_analysis(self, pressure_grid_plotting, save_path='')
#  |      This function plots the R2 pressure latitude figure shown in the SI.
#  |
#  |  reshape_daily(self, output)
#  |      This function returns two numpy arrays, one for each vertically resolved variable (heating and moistening).
#  |      Dimensions of expected input are num_samples by 128 (number of target features).
#  |      Output argument is espected to be have dimensions of num_samples by features.
#  |      Heating is expected to be the first feature, and moistening is expected to be the second feature.
#  |      Data is expected to use a stride_sample of 6. (12 samples per day, 20 min timestep).
#  |
#  |  reshape_npy(self, var_arr, var_arr_dim)
#  |      This function reshapes the a variable in numpy such that time gets its own axis (instead of being num_samples x num_levels).
#  |      Shape of target would be (timestep, lat/lon combo, num_levels)
#  |
#  |  reweight_preds(self, data_split)
#  |      weights predictions assuming V1 outputs using the output_weighting function
#  |
#  |  reweight_target(self, data_split)
#  |      data_split should be train, val, scoring, or test
#  |      weights target variables assuming V1 outputs using the output_weighting function
#  |
#  |  save_as_npy(self, data_split, save_path='', save_latlontime_dict=False)
#  |      This function saves the training data as a .npy file. Prefix should be train or val.
#  |
#  |  set_filelist(self, data_split)
#  |      This function sets the filelists corresponding to data splits for train, val, scoring, and test.
#  |
#  |  set_pressure_grid(self, data_split)
#  |      This function sets the pressure weighting for metrics.
#  |
#  |  set_regexps(self, data_split, regexps)
#  |      This function sets the regular expressions used for getting the filelist for train, val, scoring, and test.
#  |
#  |  set_stride_sample(self, data_split, stride_sample)
#  |      This function sets the stride_sample for train, val, scoring, and test.
#  |
#  |  set_to_v1_vars(self)
#  |      This function sets the inputs and outputs to the V1 subset.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  load_h5_file(load_path='')
#  |      This function loads the prediction .h5 file.
#  |
#  |  load_npy_file(load_path='')
#  |      This function loads the prediction .npy file.
#  |
#  |  ls(dir_path='')
#  |      You can treat this as a Python wrapper for the bash command "ls".
#  |
#  |  reshape_input_for_cnn(npy_input, save_path='')
#  |      This function reshapes a numpy input array to be compatible with CNN training.
#  |      Each variable becomes its own channel.
#  |      For the input there are 6 channels, each with 60 vertical levels.
#  |      The last 4 channels correspond to scalars repeated across all 60 levels.
#  |      This is for V1 data only! (V2 data has more variables)
#  |
#  |  reshape_target_for_cnn(npy_target, save_path='')
#  |      This function reshapes a numpy target array to be compatible with CNN training.
#  |      Each variable becomes its own channel.
#  |      For the input there are 6 channels, each with 60 vertical levels.
#  |      The last 4 channels correspond to scalars repeated across all 60 levels.
#  |      This is for V1 data only! (V2 data has more variables)
#  |
#  |  reshape_target_from_cnn(npy_predict_cnn, save_path='')
#  |      This function reshapes CNN target to (num_samples, 128) for standardized metrics.
#  |      This is for V1 data only! (V2 data has more variables)
#  |
#  |  set_plot_params()
#  |      This function sets the plot parameters for matplotlib.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
grid_path = '/GitHub/ClimSim/grid_info/ClimSim_low-res_grid-info.nc'
norm_path = '/GitHub/ClimSim/preprocessing/normalizations/'

# %%
grid_info = xr.open_dataset(grid_path)
input_mean = xr.open_dataset(norm_path + 'inputs/input_mean.nc')
input_max = xr.open_dataset(norm_path + 'inputs/input_max.nc')
input_min = xr.open_dataset(norm_path + 'inputs/input_min.nc')
output_scale = xr.open_dataset(norm_path + 'outputs/output_scale.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda3\Lib\site-packages\xarray\backends\file_manager.py:209, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     208 try:
# --> 209     file = self._cache[self._key]
#     210 except KeyError:
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\lru_cache.py:55, in LRUCache.__getitem__(self, key)
#      54 with self._lock:
# ---> 55     value = self._cache[key]
#      56     self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x0000022A31E3C180>, ('E:\\GitHub\\ClimSim\\grid_info\\ClimSim_low-res_grid-info.nc',), 'r', (('mmap', None), ('version', 2)), '1abf67db-1550-4fc0-b382-242ccd9d81e1']
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 grid_info = xr.open_dataset(grid_path)
#       2 input_mean = xr.open_dataset(norm_path + 'inputs/input_mean.nc')
#       3 input_max = xr.open_dataset(norm_path + 'inputs/input_max.nc')
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\api.py:539, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     527 decoders = _resolve_decoders_kwargs(
#     528     decode_cf,
#     529     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     535     decode_coords=decode_coords,
#     536 )
#     538 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 539 backend_ds = backend.open_dataset(
#     540     filename_or_obj,
#     541     drop_variables=drop_variables,
#     542     **decoders,
#     543     **kwargs,
#     544 )
#     545 ds = _dataset_from_backend_dataset(
#     546     backend_ds,
#     547     filename_or_obj,
#    (...)
#     555     **kwargs,
#     556 )
#     557 return ds
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\scipy_.py:303, in ScipyBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, mode, format, group, mmap, lock)
#     301 store_entrypoint = StoreBackendEntrypoint()
#     302 with close_on_error(store):
# --> 303     ds = store_entrypoint.open_dataset(
#     304         store,
#     305         mask_and_scale=mask_and_scale,
#     306         decode_times=decode_times,
#     307         concat_characters=concat_characters,
#     308         decode_coords=decode_coords,
#     309         drop_variables=drop_variables,
#     310         use_cftime=use_cftime,
#     311         decode_timedelta=decode_timedelta,
#     312     )
#     313 return ds
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\store.py:28, in StoreBackendEntrypoint.open_dataset(self, store, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      16 def open_dataset(
#      17     self,
#      18     store,
#    (...)
#      26     decode_timedelta=None,
#      27 ):
# ---> 28     vars, attrs = store.load()
#      29     encoding = store.get_encoding()
#      31     vars, attrs, coord_names = conventions.decode_cf_variables(
#      32         vars,
#      33         attrs,
#    (...)
#      40         decode_timedelta=decode_timedelta,
#      41     )
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\common.py:128, in AbstractDataStore.load(self)
#     106 def load(self):
#     107     """
#     108     This loads the variables and attributes simultaneously.
#     109     A centralized loading function makes it easier to create
#    (...)
#     125     are requested, so care should be taken to make sure its fast.
#     126     """
#     127     variables = FrozenDict(
# --> 128         (_decode_variable_name(k), v) for k, v in self.get_variables().items()
#     129     )
#     130     attributes = FrozenDict(self.get_attrs())
#     131     return variables, attributes
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\scipy_.py:170, in ScipyDataStore.get_variables(self)
#     168 def get_variables(self):
#     169     return FrozenDict(
# --> 170         (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     171     )
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\scipy_.py:159, in ScipyDataStore.ds(self)
#     157 @property
#     158 def ds(self):
# --> 159     return self._manager.acquire()
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\file_manager.py:191, in CachingFileManager.acquire(self, needs_lock)
#     176 def acquire(self, needs_lock=True):
#     177     """Acquire a file object from the manager.
#     178
#     179     A new file is only opened if it has expired from the
#    (...)
#     189         An open file object, as returned by ``opener(*args, **kwargs)``.
#     190     """
# --> 191     file, _ = self._acquire_with_cache_info(needs_lock)
#     192     return file
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\file_manager.py:215, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     213     kwargs = kwargs.copy()
#     214     kwargs["mode"] = self._mode
# --> 215 file = self._opener(*self._args, **kwargs)
#     216 if self._mode == "w":
#     217     # ensure file doesn't get overridden when opened again
#     218     self._mode = "a"
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\scipy_.py:98, in _open_scipy_netcdf(filename, mode, mmap, version)
#      95     filename = io.BytesIO(filename)
#      97 try:
# ---> 98     return scipy.io.netcdf_file(filename, mode=mode, mmap=mmap, version=version)
#      99 except TypeError as e:  # netcdf3 message is obscure in this case
#     100     errmsg = e.args[0]
#
# File D:\anaconda3\Lib\site-packages\scipy\io\_netcdf.py:278, in netcdf_file.__init__(self, filename, mode, mmap, version, maskandscale)
#     275 self._attributes = {}
#     277 if mode in 'ra':
# --> 278     self._read()
#
# File D:\anaconda3\Lib\site-packages\scipy\io\_netcdf.py:605, in netcdf_file._read(self)
#     603 # Read file headers and set data.
#     604 self._read_numrecs()
# --> 605 self._read_dim_array()
#     606 self._read_gatt_array()
#     607 self._read_var_array()
#
# File D:\anaconda3\Lib\site-packages\scipy\io\_netcdf.py:615, in netcdf_file._read_dim_array(self)
#     613 header = self.fp.read(4)
#     614 if header not in [ZERO, NC_DIMENSION]:
# --> 615     raise ValueError("Unexpected header.")
#     616 count = self._unpack_int()
#     618 for dim in range(count):
#
# ValueError: Unexpected header.

# %%
grid_path
# Out:
# '/ocean/projects/atm200007p/jlin96/ClimSim/grid_info/ClimSim_low-res_grid-info.nc'

# %%
grid_info = xr.open_dataset('./grid_info/ClimSim_low-res_grid-info.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda3\Lib\site-packages\xarray\backends\file_manager.py:209, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     208 try:
# --> 209     file = self._cache[self._key]
#     210 except KeyError:
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\lru_cache.py:55, in LRUCache.__getitem__(self, key)
#      54 with self._lock:
# ---> 55     value = self._cache[key]
#      56     self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x0000022A31E3C180>, ('E:\\GitHub\\ClimSim\\grid_info\\ClimSim_low-res_grid-info.nc',), 'r', (('mmap', None), ('version', 2)), 'ac4607ae-77db-4d20-a9cc-99449e2cd60a']
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 grid_info = xr.open_dataset('./grid_info/ClimSim_low-res_grid-info.nc')
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\api.py:539, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     527 decoders = _resolve_decoders_kwargs(
#     528     decode_cf,
#     529     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     535     decode_coords=decode_coords,
#     536 )
#     538 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 539 backend_ds = backend.open_dataset(
#     540     filename_or_obj,
#     541     drop_variables=drop_variables,
#     542     **decoders,
#     543     **kwargs,
#     544 )
#     545 ds = _dataset_from_backend_dataset(
#     546     backend_ds,
#     547     filename_or_obj,
#    (...)
#     555     **kwargs,
#     556 )
#     557 return ds
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\scipy_.py:303, in ScipyBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, mode, format, group, mmap, lock)
#     301 store_entrypoint = StoreBackendEntrypoint()
#     302 with close_on_error(store):
# --> 303     ds = store_entrypoint.open_dataset(
#     304         store,
#     305         mask_and_scale=mask_and_scale,
#     306         decode_times=decode_times,
#     307         concat_characters=concat_characters,
#     308         decode_coords=decode_coords,
#     309         drop_variables=drop_variables,
#     310         use_cftime=use_cftime,
#     311         decode_timedelta=decode_timedelta,
#     312     )
#     313 return ds
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\store.py:28, in StoreBackendEntrypoint.open_dataset(self, store, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      16 def open_dataset(
#      17     self,
#      18     store,
#    (...)
#      26     decode_timedelta=None,
#      27 ):
# ---> 28     vars, attrs = store.load()
#      29     encoding = store.get_encoding()
#      31     vars, attrs, coord_names = conventions.decode_cf_variables(
#      32         vars,
#      33         attrs,
#    (...)
#      40         decode_timedelta=decode_timedelta,
#      41     )
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\common.py:128, in AbstractDataStore.load(self)
#     106 def load(self):
#     107     """
#     108     This loads the variables and attributes simultaneously.
#     109     A centralized loading function makes it easier to create
#    (...)
#     125     are requested, so care should be taken to make sure its fast.
#     126     """
#     127     variables = FrozenDict(
# --> 128         (_decode_variable_name(k), v) for k, v in self.get_variables().items()
#     129     )
#     130     attributes = FrozenDict(self.get_attrs())
#     131     return variables, attributes
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\scipy_.py:170, in ScipyDataStore.get_variables(self)
#     168 def get_variables(self):
#     169     return FrozenDict(
# --> 170         (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     171     )
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\scipy_.py:159, in ScipyDataStore.ds(self)
#     157 @property
#     158 def ds(self):
# --> 159     return self._manager.acquire()
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\file_manager.py:191, in CachingFileManager.acquire(self, needs_lock)
#     176 def acquire(self, needs_lock=True):
#     177     """Acquire a file object from the manager.
#     178
#     179     A new file is only opened if it has expired from the
#    (...)
#     189         An open file object, as returned by ``opener(*args, **kwargs)``.
#     190     """
# --> 191     file, _ = self._acquire_with_cache_info(needs_lock)
#     192     return file
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\file_manager.py:215, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     213     kwargs = kwargs.copy()
#     214     kwargs["mode"] = self._mode
# --> 215 file = self._opener(*self._args, **kwargs)
#     216 if self._mode == "w":
#     217     # ensure file doesn't get overridden when opened again
#     218     self._mode = "a"
#
# File D:\anaconda3\Lib\site-packages\xarray\backends\scipy_.py:98, in _open_scipy_netcdf(filename, mode, mmap, version)
#      95     filename = io.BytesIO(filename)
#      97 try:
# ---> 98     return scipy.io.netcdf_file(filename, mode=mode, mmap=mmap, version=version)
#      99 except TypeError as e:  # netcdf3 message is obscure in this case
#     100     errmsg = e.args[0]
#
# File D:\anaconda3\Lib\site-packages\scipy\io\_netcdf.py:278, in netcdf_file.__init__(self, filename, mode, mmap, version, maskandscale)
#     275 self._attributes = {}
#     277 if mode in 'ra':
# --> 278     self._read()
#
# File D:\anaconda3\Lib\site-packages\scipy\io\_netcdf.py:605, in netcdf_file._read(self)
#     603 # Read file headers and set data.
#     604 self._read_numrecs()
# --> 605 self._read_dim_array()
#     606 self._read_gatt_array()
#     607 self._read_var_array()
#
# File D:\anaconda3\Lib\site-packages\scipy\io\_netcdf.py:615, in netcdf_file._read_dim_array(self)
#     613 header = self.fp.read(4)
#     614 if header not in [ZERO, NC_DIMENSION]:
# --> 615     raise ValueError("Unexpected header.")
#     616 count = self._unpack_int()
#     618 for dim in range(count):
#
# ValueError: Unexpected header.
